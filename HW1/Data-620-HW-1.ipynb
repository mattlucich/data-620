# %% [markdown]
# ## Data 620: Homework #1

# %% [markdown]
# ### By Matthew Lucich

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()

G.add_edge('Jane', 'Ike')

G.add_edge('Ike', 'Heather')

G.add_edge('Heather', 'Fernando')
G.add_edge('Heather', 'Garth')

G.add_edge('Fernando', 'Garth')
G.add_edge('Fernando', 'Carol')
G.add_edge('Fernando', 'Andre')
G.add_edge('Fernando', 'Diane')

G.add_edge('Garth', 'Diane')
G.add_edge('Garth', 'Beverly')
G.add_edge('Garth', 'Ed')

G.add_edge('Carol', 'Diane')
G.add_edge('Carol', 'Andre')

G.add_edge('Diane', 'Andre')
G.add_edge('Diane', 'Beverly')
G.add_edge('Diane', 'Ed')

G.add_edge('Ed', 'Beverly')

G.add_edge('Andre', 'Beverly')

G.edges(data=True)
# Out:
# EdgeDataView([('Jane', 'Ike', {}), ('Ike', 'Heather', {}), ('Heather', 'Fernando', {}), ('Heather', 'Garth', {}), ('Fernando', 'Garth', {}), ('Fernando', 'Carol', {}), ('Fernando', 'Andre', {}), ('Fernando', 'Diane', {}), ('Garth', 'Diane', {}), ('Garth', 'Beverly', {}), ('Garth', 'Ed', {}), ('Carol', 'Diane', {}), ('Carol', 'Andre', {}), ('Andre', 'Diane', {}), ('Andre', 'Beverly', {}), ('Diane', 'Beverly', {}), ('Diane', 'Ed', {}), ('Beverly', 'Ed', {})])

# %%
nx.draw_networkx(G, pos=nx.spring_layout(G), node_color='gray', edge_color='purple')

# %% [markdown]
# ### References

# %% [markdown]
# Introduction to Data Science - NetworkX Tutorial, YouTube, https://www.youtube.com/watch?v=PouhDHfssYA <br>
# NetworkX Official Documentation, https://networkx.org/documentation/stable/index.html
